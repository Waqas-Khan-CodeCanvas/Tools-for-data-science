# %% [markdown]
# # My Final Data Science Notebook

# %% [markdown]
# ## Introduction
# This notebook showcases basic concepts, tools, and operations used in Data Science.

# %% [markdown]
# ## Data Science Languages
# Here are some commonly used languages in data science:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# ## Data Science Libraries
# Some popular libraries for data science tasks are:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn

# %% [markdown]
# ## Data Science Tools
#
# | Tool               | Purpose                        |
# |-------------------|--------------------------------|
# | Jupyter Notebook  | Interactive coding and testing |
# | GitHub            | Version control and sharing    |
# | VS Code           | Code editing                   |
# | Tableau           | Data visualization             |

# %% [markdown]
# ## Arithmetic Expression Examples
# In this section, we demonstrate basic arithmetic operations using Python.
